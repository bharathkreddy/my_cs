# %% [markdown]
# # MetaClasses
# > Metaclases are deeper magic than 99% of users should ever worry about. If you wonder whether you need them, you don't. The people who actually need them know with certainity that they need them, and don't need an explanation why.  - _Tim Peters_
